# %%
import cv2
import matplotlib.pyplot as plt

# %%
einstein = cv2.imread("data/einstein.jpg", 0)

plt.figure(), plt.title("Einstein"), plt.imshow(einstein, cmap="gray"), plt.axis("off");

# %% [markdown]
# # Classification

# %%
face_cascade = cv2.CascadeClassifier("data/haarcascade_frontalface_default.xml")

face_rect = face_cascade.detectMultiScale(einstein)

for (x,y,w,h) in face_rect:
    
    cv2.rectangle(einstein, (x,y), (x+w, y+h), (255,255,255), 10)
    
plt.figure(), plt.title("Einstein"), plt.imshow(einstein, cmap="gray"), plt.axis("off");

# %% [markdown]
# -----

# %% [markdown]
# ___

# %%
barce = cv2.imread("data/barcelona.jpg", 0)

plt.figure(), plt.title("Barcelona"), plt.imshow(barce, cmap="gray"), plt.axis("off");

# %%
face_rect = face_cascade.detectMultiScale(barce, minNeighbors=7)

for (x,y,w,h) in face_rect:
    
    cv2.rectangle(barce, (x,y), (x+w, y+h), (255,255,255), 10)
    
plt.figure(figsize=(7,7)), plt.title("Barce"), plt.imshow(barce, cmap="gray"), plt.axis("off");

# %% [markdown]
# # Face Detection with Camera

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    if ret:
        
        face_rect = face_cascade.detectMultiScale(frame, minNeighbors=7)
        
        for (x,y,w,h) in face_rect:
            cv2.rectangle(frame, (x,y), (x+w, y+h), (255,255,255), 3)
        cv2.imshow("Face Detect", frame)
        
    if cv2.waitKey(1) & 0xFF == ord("q"): break
        
cap.release()
cv2.destroyAllWindows()
